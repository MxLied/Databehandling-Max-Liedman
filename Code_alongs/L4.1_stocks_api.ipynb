# %% [markdown]
# # API
#
# * Application programming interface

# %%
from dotenv import load_dotenv
import os, requests
import pandas as pd

load_dotenv()
api_key = os.getenv("ALPHA_API_KEY")
symbols = ["AAPL", "NVDA", "TSLA", "IBM"]
stock_list = []

for symbol in symbols:
    function = "TIME_SERIES_INTRADAY"
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={symbol}&interval=5min&apikey={api_key}'
    data = requests.get(url).json()
    stock_list.append(data)

print(data)

# %%
len(stock_list)
# Out:
# 4

# %%
stock_list[0].keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (5min)'])

# %%
# datetime1: dict
# datetime2: dict
pd.DataFrame(stock_list[0]["Time Series (5min)"]).T.head()
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2022-11-04 20:00:00  138.0798  138.1800  138.0700  138.1200     13042
# 2022-11-04 19:55:00  138.1400  138.1400  138.0700  138.0700      9587
# 2022-11-04 19:50:00  138.1200  138.1300  138.0700  138.1200      3695
# 2022-11-04 19:45:00  138.1600  138.1600  138.1100  138.1200      4015
# 2022-11-04 19:40:00  138.1600  138.1700  138.1500  138.1700      4399

# %%
load_dotenv()
api_key = os.getenv("ALPHA_API_KEY")
symbols = ["AAPL", "NVDA", "TSLA", "IBM"]
stock_list = []

for symbol in symbols:
    function = "TIME_SERIES_INTRADAY"
    url = f"https://www.alphavantage.co/query?function={function}&symbol={symbol}&interval=60min&apikey={api_key}"
    data = requests.get(url).json()
    df = pd.DataFrame(data["Time Series (60min)"]).T
    stock_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [34], line 10
#       8 url = f"https://www.alphavantage.co/query?function={function}&symbol={symbol}&interval=60min&apikey={api_key}"
#       9 data = requests.get(url).json()
# ---> 10 df = pd.DataFrame(data["Time Series (60min)"]).T
#      11 stock_list.append(df)
#
# KeyError: 'Time Series (60min)'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 2022-11-04 20:00:00 to 2022-10-26 10:00:00
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    100 non-null    object
#  1   2. high    100 non-null    object
#  2   3. low     100 non-null    object
#  3   4. close   100 non-null    object
#  4   5. volume  100 non-null    object
# dtypes: object(5)
# memory usage: 4.7+ KB

# %%
df.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. volume'], dtype='object')

# %%
print(f"{len(stock_list) = }")
stock_list[:2]
# Out:
# len(stock_list) = 4
# [                      1. open   2. high    3. low  4. close 5. volume
#  2022-11-04 20:00:00  138.2200  138.2200  138.0700  138.1200     64681
#  2022-11-04 19:00:00  138.1900  138.2400  138.1300  138.2300     38808
#  2022-11-04 18:00:00  138.2000  138.3000  138.0700  138.2138    116813
#  2022-11-04 17:00:00  138.3900  138.6200  138.1200  138.2400   3410067
#  2022-11-04 16:00:00  136.7700  138.5000  136.6200  138.3900  20985511
#  ...                       ...       ...       ...       ...       ...
#  2022-10-28 05:00:00  143.4516  146.1271  143.4516  146.0972    155019
#  2022-10-27 20:00:00  145.0589  145.7478  144.8592  145.1087    312666
#  2022-10-27 19:00:00  145.7377  147.0955  144.4799  144.9591   1018580
#  2022-10-27 18:00:00  143.0621  148.0040  139.1687  145.6080   5998211
#  2022-10-27 17:00:00  144.5597  145.6579  135.7743  142.9324  16391852
#
00:00       NaN       NaN       NaN       NaN       NaN
# 2022-11-04 17:00:00  136.9600  137.0000  136.8800  137.0000     91495
# 2022-11-04 16:00:00  136.5200  137.0800  136.3500  137.0000    938626
# ...                       ...       ...       ...       ...       ...
# 2022-10-26 14:00:00  135.3500  135.7500  135.1600  135.6100    498893
# 2022-10-26 13:00:00  135.7390  135.8630  135.2301  135.3500    393057
# 2022-10-26 12:00:00  135.2700  135.7800  135.2400  135.7350    651240
# 2022-10-26 11:00:00  133.6400  135.4965  133.5411  135.2800   1086459
# 2022-10-26 10:00:00  132.7000  134.4600  132.6400  133.6050    485533
#
# [120 rows x 20 columns]

# %%
import plotly.express as px

px.line(
    stocks,
    x=stocks.index,
    y=symbols,
    labels={"variable": "Stock", "value": "Value in (USD)", "index": "Date"},
    title="Stocks in one week",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 3
#       1 import plotly.express as px
# ----> 3 px.line(
#       4     stocks,
#       5     x=stocks.index,
#       6     y=symbols,
#       7     labels={"variable": "Stock", "value": "Value in (USD)", "index": "Date"},
#       8     title="Stocks in one week",
#       9 )
#
# File c:\Users\maxim\.virtualenvs\Databehandling-Max-Liedman-7Jl1bF7R\lib\site-packages\plotly\express\_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
#     261     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#
# File c:\Users\maxim\.virtualenvs\Databehandling-Max-Liedman-7Jl1bF7R\lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File c:\Users\maxim\.virtualenvs\Databehandling-Max-Liedman-7Jl1bF7R\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\maxim\.virtualenvs\Databehandling-Max-Liedman-7Jl1bF7R\lib\site-packages\plotly\express\_core.py:1245, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1242         col_name = _check_name_not_reserved(field, reserved_names)
#    1244     if length and len(argument) != length:
# -> 1245         raise ValueError(
#    1246             "All arguments should have the same length. "
#    1247             "The length of argument `%s` is %d, whereas the "
#    1248             "length of  previously-processed arguments %s is %d"
#    1249             % (field, len(argument), str(list(df_output.columns)), length)
#    1250         )
#    1251     df_output[str(col_name)] = to_unindexed_series(argument)
#    1253 # Finally, update argument with column name now that column exists
#
# ValueError: All arguments should have the same length. The length of argument `y` is 4, whereas the length of  previously-processed arguments ['index'] is 120

# %% [markdown]
# ## Working with time series

# %%
print(f"{stocks.index.dtype =}")
# Out:
# stocks.index.dtype =dtype('O')

# %%
# convert dtype object to datetime
stocks.index = pd.to_datetime(stocks.index)
print(stocks.index.dtype)
stocks.head()
# Out:
# datetime64[ns]
#                       1. open   2. high    3. low  4. close 5. volume  \
# 2022-11-04 20:00:00  138.2200  138.2200  138.0700  138.1200     64681
# 2022-11-04 19:00:00  138.1900  138.2400  138.1300  138.2300     38808
# 2022-11-04 18:00:00  138.2000  138.3000  138.0700  138.2138    116813
# 2022-11-04 17:00:00  138.3900  138.6200  138.1200  138.2400   3410067
# 2022-11-04 16:00:00  136.7700  138.5000  136.6200  138.3900  20985511
#
#                       1. open   2. high    3. low  4. close 5. volume  \
# 2022-11-04 20:00:00  141.6100  141.8000  141.6000  141.7500     30949
# 2022-11-04 19:00:00  141.6200  141.6500  141.4900  141.6000     19844
# 2022-11-04 18:00:00  141.3200  141.6400  141.3100  141.6400     25728
# 2022-11-04 17:00:00  141.5600  141.8000  141.1500  141.2900    980091
# 2022-11-04 16:00:00  140.1800  141.8100  139.8500  141.8000   9840256
#
#                       1. open   2. high    3. low  4. close 5. volume  \
# 2022-11-04 20:00:00